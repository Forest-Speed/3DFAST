# %%
import time
import numpy as np 
import serial

# %% [markdown]
# DMD Control: DLP Lightcrafter GUI
#       -Pattern Mode
#             -Operating Mode :Pattern on the Fly
#                   -> C:\Users\Researcher\3DFAST-main\3DFAST-main\SIM_CODE\pats_121023\BMPS
#
#
# Piezo: Kinesis
#
# Camera: Ximea CamTool
#       - Save image: w:/workingdirectory/020325
#
# Benchtop Camera (SIM with Triggers):
#       HCImageLive DMD Acquisition:
#
#       DMD Trig: Blue/White
#       - Exposure 850us = 1000Hz, 683us = 1200Hz, 516us = 1500Hz (150us dark time)
#
#       HCImageLive:
#       Sequence Settings:
#       - Scan Type = High Speed Streaming
#       - Scan Settings -> define frame count
#       -           -> RAM
#       - Autosave -> TIFF -> add new folder for each recording!!!!!
#
#       Capture Settings:
#       - Define ROI -> Up to 1590 Hz for height of 128p
#       - Trigger Modes, Speed... -> Fast, Area, External: Sync Readout (internal if no DMD sync)

# %%
fname = 'Arduino_Trigs\\WF_500Hz_100mWsqmm_9.txt'

ser = serial.Serial('COM10')
f = open(fname, 'w')
t = 0 
while t<4000:
    # 40 Hz ~1min42sec
    line = ser.readline()
    line = line.decode('utf-8')
    f.write(line)
    print(line)
    #time.sleep(.0001)
    
    t += 1

f.close()
# Out:
# 304,0
#
# 303,0
#
# 304,0
#
# 300,5
#
# 305,0
#
# 302,0
#
# 302,0
#
# 297,0
#
# 300,0
#
# 296,0
#
# 298,0
#
# 295,0
#
# 293,13
#
# 296,0
#
# 294,0
#
# 298,4
#
# 293,12
#
# 300,11
#
# 295,0
#
# 299,15
#
# 294,11
#
# 299,32
#
# 297,0
#
# 295,11
#
# 299,0
#
# 297,0
#
# 299,4
#
# 298,0
#
# 299,1
#
# 294,12
#
# 299,10
#
# 298,2
#
# 300,0
#
# 297,0
#
# 297,6
#
# 298,0
#
# 295,0
#
# 299,0
#
# 294,0
#
# 298,1
#
# 293,27
#
# 299,3
#
# 295,14
#
# 299,4
#
# 298,3
#
# 300,0
#
# 298,0
#
# 297,0
#
# 298,87
#
# 296,5
#
# 300,0
#
# 298,8
#
# 300,4
#
# 297,5
#
# 300,9
#
# 299,14
#
# 304,5
#
# 298,0
#
# 302,0
#
# 301,0
#
# 298,4
#
# 304,0
#
# 297,29
#
# 305,0
#
# 297,0
#
# 301,0
#
# 297,0
#
# 300,10
#
# 296,15
#
# 300,0
#
# 298,6
#
# 291,1
#
# 301,0
#
# 300,96
#
# 294,0
#
# 295,0
#
# 303,0
#
# 297,2
#
# 302,9
#
# 299,0
#
# 304,6
#
# 301,0
#
# 300,0
#
# 301,0
#
# 295,0
#
# 300,34
#
# 297,8
#
# 300,20
#
# 297,21
#
# 304,0
#
# 299,0
#
# 300,7
#
# 300,0
#
# 299,0
#
# 299,0
#
# 297,1
#
# 302,0
#
# 297,8
#
# ...

# %%
print(time.time())
# Out:
# 1740589088.9560094

# %%
f.close()

# %%
cap = cv.VideoCapture(1)
if not cap.isOpened():
 print("Cannot open camera")
 exit()

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        cap.release()
        cv.destroyAllWindows()
        break

    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    flipped = cv.flip(gray, 0)
    cv.imshow('frame', gray)
    if cv.waitKey(1) == ord('q'):
        break

cap.release()
cv.destroyAllWindows()

# %%
cap.release()
cv.destroyAllWindows()

# %%
import numpy as np 
import matplotlib.pyplot as plt
fpath = 'Arduino_Trigs\\WF_500Hz_100mWsqmm_8.txt'
trig = np.loadtxt(fpath, delimiter=',')

plt.plot(trig[:,0])
plt.plot(trig[:,1]+1000 )
